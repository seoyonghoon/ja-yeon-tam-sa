# %%
import numpy as np
from matplotlib import cm
from matplotlib.colors import Normalize
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

N = 10000 #경사하강법 반복횟수
alpha = 0.001 #학습률
alt = np.array([750, 780, 804, 849, 886,
    935, 978, 1047, 1088, 1154,
    1217, 1304, 1368, 1449, 1520,
    1629, 1695, 1788, 1870, 1947]) #해발고도 리스트
grad = np.array([
    0.043, 0.053, 0.063, 0.074, 0.079,
    0.092, 0.098, 0.105, 0.114, 0.114,
    0.129, 0.138, 0.156, 0.147, 0.154,
    0.158, 0.178, 0.179, 0.191, 0.195]) #경사 리스트(각 x, dy/dx 기울기 o)
fatigue = np.array([0.42, 0.57, 0.38, 0.61, 0.47,
    0.53, 0.44, 0.66, 0.36, 0.58,
    0.49, 0.63, 0.41, 0.55, 0.46,
    0.69, 0.37, 0.52, 0.43, 0.60]) #피로도 리스트
v = np.array([3.9, 3.8, 3.7, 3.5, 3.4,
    3.2, 3.1, 2.9, 2.8, 2.7,
    2.5, 2.4, 2.2, 2.1, 2.0,
    1.8, 1.7, 1.6, 1.4, 1.3]) #속도 리스트

R2s = np.array([]) #결정계수 리스트

# 정규화
altnn = np.array([np.min(alt), np.max(alt)-np.min(alt)])
gradnn = np.array([np.min(grad), np.max(grad)-np.min(grad)])
fatiguenn = np.array([np.min(fatigue), np.max(fatigue)-np.min(fatigue)])
vnn = np.array([np.min(v), np.max(v)-np.min(v)])

altN = (alt - altnn[0]) / altnn[1]
gradN = (grad - gradnn[0]) / gradnn[1]
fatigueN = (fatigue - fatiguenn[0]) / fatiguenn[1]
vN = (v - vnn[0]) / vnn[1]


# 다항함수 회귀
polynomialC = np.random.normal(0, 1, 10)
polynomialV = [altN**2, gradN**2, fatigueN**2, altN*gradN, gradN*fatigueN, fatigueN*altN, altN, gradN, fatigueN, np.ones(len(alt))] #DelCP역할

def polynomial(a, g, f):
    return np.dot(polynomialC, [a*a, g*g, f*f, a*g, g*f, f*a, a, g, f, 1])

def P(a, g, f):#유니버설 함수용 polynomial()
    a, g, f=(a-altnn[0])/altnn[1],(g-gradnn[0])/gradnn[1],(f-fatiguenn[0])/fatiguenn[1]
    return (polynomialC[0]*a*a+polynomialC[1]*g*g+polynomialC[2]*f*f\
            +polynomialC[3]*a*g+polynomialC[4]*g*f+polynomialC[5]*f*a\
            +polynomialC[6]*a+polynomialC[7]*g+polynomialC[8]*f+polynomialC[9])*vnn[1]+vnn[0]

def calcY():
    return [polynomial(altN[i], gradN[i], fatigueN[i]) for i in range(len(alt))]

#결정계수 계산
def R2():
    Y = calcY()
    ym = np.mean(vN)
    return 1 - (sum([(Y[i] - vN[i])**2 for i in range(len(alt))]))/(sum([(i - ym)**2 for i in Y]))
for _ in range(N): 
    deviation = np.array([polynomial(altN[i], gradN[i], fatigueN[i]) - vN[i] for i in range(len(alt))])
    DelCL = np.array([np.dot(deviation, polynomialV[i]) for i in range(10)])
    polynomialC -= alpha * DelCL
    if (_ + 1) % 100 == 0:
         R2s = np.append(R2s, R2())

def test(a, g, f):
    return(polynomial((a - altnn[0])/altnn[1], (g - gradnn[0])/gradnn[1], (f - fatiguenn[0])/fatiguenn[1])*vnn[1] + vnn[0])

fig = plt.figure(figsize=(16, 8))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122)

_x = np.arange(10)*30+800
_y = np.arange(10)*0.01

_xx, _yy = np.meshgrid(_x, _y)
x, y = _xx.ravel(), _yy.ravel()

graph = P(x, y, .3)

# graph 값을 0~1 범위로 정규화
norm = Normalize(graph.min(), graph.max())

# colormap 적용
colors = cm.viridis(norm(graph))

ax1.set_title('graph, fatigue=0.5')

ax1.bar3d(
    x,
    y,
    np.zeros_like(graph),
    30,
    0.01,
    graph,
    shade=True,
    color=colors
)

ax2.set_title("R2 graph")
ax2.plot(np.arange(100), R2s)

plt.show()

# %%
import numpy as np
from matplotlib import cm
from matplotlib.colors import Normalize
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

N = 30000 #경사하강법 반복횟수
alpha = 0.03 #학습률
alt = np.array([750, 780, 804, 849, 886,
    935, 978, 1047, 1088, 1154,
    1217, 1304, 1368, 1449, 1520,
    1629, 1695, 1788, 1870, 1947]) #해발고도 리스트
grad = np.array([
    0.043, 0.053, 0.063, 0.074, 0.079,
    0.092, 0.098, 0.105, 0.114, 0.114,
    0.129, 0.138, 0.156, 0.147, 0.154,
    0.158, 0.178, 0.179, 0.191, 0.195]) #경사 리스트(각 x, dy/dx 기울기 o)
fatigue = np.array([0.42, 0.57, 0.38, 0.61, 0.47,
    0.53, 0.44, 0.66, 0.36, 0.58,
    0.49, 0.63, 0.41, 0.55, 0.46,
    0.69, 0.37, 0.52, 0.43, 0.60]) #피로도 리스트
v = np.array([3.9, 3.8, 3.7, 3.5, 3.4,
    3.2, 3.1, 2.9, 2.8, 2.7,
    2.5, 2.4, 2.2, 2.1, 2.0,
    1.8, 1.7, 1.6, 1.4, 1.3]) #속도 리스트

R2s = np.array([]) #결정계수 리스트

# 정규화 [0,1] 사이
altnn = np.array([np.min(alt), np.max(alt)-np.min(alt)])
gradnn = np.array([np.min(grad), np.max(grad)-np.min(grad)])
fatiguenn = np.array([np.min(fatigue), np.max(fatigue)-np.min(fatigue)])
vnn = np.array([np.min(v), np.max(v)-np.min(v)])

altN = (alt - altnn[0]) / altnn[1]
gradN = (grad - gradnn[0]) / gradnn[1]
fatigueN = (fatigue - fatiguenn[0]) / fatiguenn[1]
vN = (v - vnn[0]) / vnn[1]

#지수함수 회귀
exponentialC = np.random.normal(0, 1, 16)

def exponential(a, g, f):
    return (np.dot(exponentialC[0:4],[a, g, f, 1])*np.exp(exponentialC[4]*a)\
    + np.dot(exponentialC[5:9],[a, g, f, 1])*np.exp(exponentialC[9]*g)\
    + np.dot(exponentialC[10:14],[a, g, f, 1])*np.exp(exponentialC[14]*f)\
    + exponentialC[15])

def E(a, g, f):#유니버설 함수버전 exponential()
     a = (a-altnn[0])/altnn[1]
     g = (g-gradnn[0])/gradnn[1]
     f = (f-fatiguenn[0])/fatiguenn[1]
     return ((exponentialC[0]*a+exponentialC[1]*g+exponentialC[2]*f+exponentialC[3])*np.exp(exponentialC[4]*a)\
     +(exponentialC[5]*a+exponentialC[6]*g+exponentialC[7]*f+exponentialC[8])*np.exp(exponentialC[9]*g)\
     +(exponentialC[10]*a+exponentialC[11]*g+exponentialC[12]*f+exponentialC[13])*np.exp(exponentialC[14]*f)\
     +exponentialC[15])*vnn[1]+vnn[0]

def calcY():
    return [exponential(altN[i], gradN[i], fatigueN[i]) for i in range(len(alt))]

#결정계수 계산
def R2():
    Y = calcY()
    ym = np.mean(vN)
    return 1 - (sum([(Y[i] - vN[i])**2 for i in range(len(alt))]))/(sum([(i - ym)**2 for i in Y]))

#학습
for _ in range(N):
        a, g, f = altN, gradN, fatigueN
        ea = np.exp(exponentialC[4]*a)
        eg = np.exp(exponentialC[9]*g)
        ef = np.exp(exponentialC[14]*f)
        DelCP = [
            a*ea,
            g*ea,
            f*ea,
            ea,
            a*(exponentialC[0]*a + exponentialC[1]*g + exponentialC[2]*f + exponentialC[3])*ea,
            a*eg,
            g*eg,
            f*eg,
            eg,
            g*(exponentialC[5]*a + exponentialC[6]*g + exponentialC[7]*f + exponentialC[8])*eg,
            a*ef,
            g*ef,
            f*ef,
            ef,
            f*(exponentialC[10]*a + exponentialC[11]*g + exponentialC[12]*f + exponentialC[13])*ef,
            np.ones_like(alt)
         ]
        deviation = np.array([exponential(a[i], g[i], f[i]) - vN[i] for i in range(len(a))])
        DelCL = np.array([np.dot(deviation, DelCP[i]) for i in range(16)])
        exponentialC -= alpha * DelCL
        if (_ + 1) % 100 == 0:
             R2s = np.append(R2s, R2())
    

def test(a, g, f):
    return exponential((a - altnn[0])/altnn[1], (g - gradnn[0])/gradnn[1], (f - fatiguenn[0])/fatiguenn[1])*vnn[1] + vnn[0]

fig = plt.figure(figsize=(16, 8))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122)

_x = np.arange(10)*30+800
_y = np.arange(10)*0.01

_xx, _yy = np.meshgrid(_x, _y)
x, y = _xx.ravel(), _yy.ravel()

graph = E(x, y, .3)

# graph 값을 0~1 범위로 정규화
norm = Normalize(graph.min(), graph.max())

# colormap 적용
colors = cm.viridis(norm(graph))

ax1.set_title('graph, fatigue=0.5')

ax1.bar3d(
    x,
    y,
    np.zeros_like(graph),
    30,
    0.01,
    graph,
    shade=True,
    color=colors
)

ax2.set_title("R2 graph")
ax2.plot(np.arange(300), R2s)

plt.show()
